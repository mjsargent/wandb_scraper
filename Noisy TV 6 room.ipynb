# %%
import matplotlib.pyplot as plt
from scraper import Line

plt.rc('font', family='serif')
plt.rc('xtick', labelsize='large')
plt.rc('ytick', labelsize='large')

# %%
# get data
no_curiosity = Line(
    run_names=[
        "vocal-snow-1526",
        "worthy-lion-1528",
        "fragrant-paper-1530",
        "denim-silence-1532",
        "good-forest-1",
    ],
    x_quantity="_step",
    y_quantity="fixed visiation counts",
    color="blue",
)

# %%
curiosity = Line(
    run_names=[
        "copper-planet-1589",
        "colorful-galaxy-1591",
        "easy-bee-1593",
        "resilient-vortex-1595",
        "worthy-snow",
    ],
    x_quantity="_step",
    y_quantity="fixed visiation counts",
    color="#338B4E",
)

# %%
AMA = Line(
    run_names=[
        "radiant-wood-1506",
        "spring-glade-1508",
        "dutiful-sunset-1510",
        "kind-thunder-1512",
        "desert-salad-1514",
    ],
    x_quantity="_step",
    y_quantity="fixed visiation counts",
    color="#95275F",
)

# %%
RND = Line(
    run_names=[
        "efficient-cherry-2050",
        "wise-dream-2047",
        "solar-pond-2044",
        "robust-breeze-2041",
        "floral-breeze-2038",
    ],
    x_quantity="_step",
    y_quantity="largest non zero",
    color="#C565C7",
)

# %%
disagreement = Line(
    run_names=[
        "playful-disco-2102",
        "drawn-terrain-2100",
        "soft-salad-2098",
        "rose-river-2096",
        "robust-music-2094",
    ],
    x_quantity="_step",
    y_quantity="largest non zero",
    color="#756AD9",
)

# %%
# plot lines
no_curiosity.plot_line(label="A2C", color="#5FC6DB")
curiosity.plot_line(label="MSE", color="#338B4E")
AMA.plot_line(label="AMA", color="#95275F")
RND.plot_line(label="RND", color="#5882FA")
disagreement.plot_line(label="Ensemble", color="#FE9A2E")

# make graph pretty
plt.xlabel("Training Steps", fontsize="x-large")
plt.ylabel("Novel States Visited", fontsize="x-large")
plt.xlim(-2000,250000)
plt.ylim(0,80)
plt.title("MultiRoom-N6-v0 with Noisy TV", fontsize="xx-large")
plt.tight_layout()
plt.savefig("MultiRoom-N6-v0 with Noisy TV.png", dpi=1200)
plt.legend()
plt.show()
