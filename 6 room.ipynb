# %%
import matplotlib.pyplot as plt
from scraper import Line

plt.rc('font', family='serif')
plt.rc('xtick', labelsize='large')
plt.rc('ytick', labelsize='large')

# %%
# get data
no_curiosity = Line(
    run_names=[
        "autumn-pine-1527",
        "eager-sky-1529",
        "dainty-vortex-1531",
        "classic-donkey-1533",
        "stoic-spaces",
    ],
    x_quantity="_step",
    y_quantity="fixed visiation counts",
    color="blue",
)

# %%
curiosity = Line(
    run_names=[
        "comfy-blaze-1590",
        "snowy-night-1592",
        "sparkling-river-1594",
        "divine-glitter-1596",
        "copper-mou-1598",
    ],
    x_quantity="_step",
    y_quantity="fixed visiation counts",
    color="red",
)

# %%
AMA = Line(
    run_names=[
        "robust-microwave-1515",
        "driven-fog-1513",
        "fragrant-wind-1511",
        "wandering-breeze-1509",
        "brisk-disco-1507",
    ],
    x_quantity="_step",
    y_quantity="fixed visiation counts",
    color="green",
)

# %%
RND = Line(
    run_names=[
        "efficient-cherry-2050",
        "wise-dream-2047",
        "solar-pond-2044",
        "robust-breeze-2041",
        "floral-breeze-2038",
    ],
    x_quantity="_step",
    y_quantity="largest non zero",
    color="orange",
)

# %%
disagreement = Line(
    run_names=[
        "playful-disco-2102",
        "drawn-terrain-2100",
        "soft-salad-2098",
        "rose-river-2096",
        "robust-music-2094",
    ],
    x_quantity="_step",
    y_quantity="largest non zero",
    color="purple",
)

# %%
# plot lines
no_curiosity.plot_line(label="A2C")
curiosity.plot_line(label="MSE")
AMA.plot_line(label="AMA")
RND.plot_line(label="RND")
disagreement.plot_line(label="Ensemble")

# make graph pretty
plt.xlabel("Training Steps", fontsize="x-large")
plt.ylabel("Novel States Visited", fontsize="x-large")
plt.xlim(-2000,250000)
plt.ylim(0,80)
plt.title("MultiRoom-N6-v0 without Noisy TV")
plt.legend()
plt.show()
