# %%
import matplotlib.pyplot as plt
from scraper import Line

plt.rc('font', family='serif')
plt.rc('xtick', labelsize='large')
plt.rc('ytick', labelsize='large')

# %%
# get data
no_curiosity = Line(
    run_names=[
        "blooming-glade-1549",
        "drawn-pond-1551",
        "lyric-firefly-1553",
        "comfy-pond-1555",
        "breezy-frog-1557",
    ],
    x_quantity="_step",
    y_quantity="fixed visiation counts",
    color="blue",
)

# %%
curiosity = Line(
    run_names=[
        "devout-frost-1569",
        "bumbling-music-1571",
        "young-thunder-1573",
        "silvery-wave-1575",
        "clear-smoke-1577",
    ],
    x_quantity="_step",
    y_quantity="fixed visiation counts",
    color="red",
)

# %%
AMA = Line(
    run_names=[
        "unique-thunder-1559",
        "woven-fire-1561",
        "frosty-pyramid-1563",
        "elated-resonance-1565",
        "fast-eon-1567",
    ],
    x_quantity="_step",
    y_quantity="fixed visiation counts",
    color="green",
)

# %%
# plot lines
no_curiosity.plot_line()
curiosity.plot_line()
AMA.plot_line()

# make graph pretty
plt.xlabel("Training Steps", fontsize="x-large")
plt.ylabel("Novel States Visited", fontsize="x-large")
plt.xlim(-2000,250000)
plt.ylim(0,30)
plt.title("Novel States Visited MultiRoom-N4-S5-v0")
plt.show()
