# %%
import matplotlib.pyplot as plt
from scraper import Line

plt.rc('font', family='serif')
plt.rc('xtick', labelsize='large')
plt.rc('ytick', labelsize='large')

# %%
# get data
no_curiosity = Line(
    run_names=[
        "blooming-glade-1549",
        "drawn-pond-1551",
        "lyric-firefly-1553",
        "comfy-pond-1555",
        "breezy-frog-1557",
    ],
    x_quantity="_step",
    y_quantity="fixed visiation counts",
    color="blue",
)

# %%
curiosity = Line(
    run_names=[
        "devout-frost-1569",
        "bumbling-music-1571",
        "young-thunder-1573",
        "silvery-wave-1575",
        "clear-smoke-1577",
    ],
    x_quantity="_step",
    y_quantity="fixed visiation counts",
    color="#338B4E",
)

# %%
AMA = Line(
    run_names=[
        "unique-thunder-1559",
        "woven-fire-1561",
        "frosty-pyramid-1563",
        "elated-resonance-1565",
        "fast-eon-1567",
    ],
    x_quantity="_step",
    y_quantity="fixed visiation counts",
    color="#95275F",
)

# %%
RND = Line(
    run_names=[
        "lunar-yogurt-2065",
        "pretty-cherry-2062",
        "blooming-valley-2060",
        "ruby-waterfall-2057",
        "dulcet-blaze-2053",
    ],
    x_quantity="_step",
    y_quantity="largest non zero",
    color="#C565C7",
)

# %%
disagreement = Line(
    run_names=[
        "sleek-surf-2112",
        "crimson-deluge-2110",
        "atomic-shape-2108",
        "flowing-field-2106",
        "royal-armadillo-2104",
    ],
    x_quantity="_step",
    y_quantity="largest non zero",
    color="#756AD9",
)

# %%
# plot lines
no_curiosity.plot_line(label="A2C", color="#5FC6DB")
curiosity.plot_line(label="MSE", color="#338B4E")
AMA.plot_line(label="AMA", color="#95275F")
RND.plot_line(label="RND", color="#5882FA")
disagreement.plot_line(label="Ensemble", color="#FE9A2E")

# make graph pretty
plt.xlabel("Training Steps", fontsize="x-large")
plt.ylabel("Novel States Visited", fontsize="x-large")
plt.xlim(-2000,250000)
plt.ylim(0,30)
plt.title("MultiRoom-N4-S5-v0 with Noisy TV", fontsize="xx-large")
plt.tight_layout()
plt.savefig("MultiRoom-N4-S5-v0 with Noisy TV.png", dpi=1200)
plt.legend()
plt.show()
